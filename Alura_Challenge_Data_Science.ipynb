# %% [markdown]
# <a href="https://colab.research.google.com/github/JvNeo/Estudo_Pandas/blob/main/Alura_Challenge_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url = 'https://raw.githubusercontent.com/sthemonica/alura-voz/refs/heads/main/Dados/Telco-Customer-Churn.json'

import pandas as pd

# %%
dados = pd.read_json(url)

# %%
dados
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %%
dados_customer = pd.json_normalize(dados['customer'])

# %%
dados = dados.drop(columns='customer').join(dados_customer)

# %%
dados
# Out:
#       customerID Churn                                              phone  \
# 0     0002-ORFBO    No     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1     0003-MKNFE    No    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2     0004-TLHLJ   Yes     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3     0011-IGKFF   Yes     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4     0013-EXCHZ   Yes     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263  9992-RRAMN   Yes    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264  9992-UJOEL    No     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265  9993-LHIEB    No     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  9995-HOTOH    No  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account  gender  \
# 0     {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# ...                                                 ...     ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
#
#       SeniorCitizen Partner Dependents  tenure
# 0                 0     Yes        Yes       9
# 1                 0      No         No       9
# 2                 0      No         No       4
# 3                 1     Yes         No      13
# 4                 1     Yes         No       3
# ...             ...     ...        ...     ...
# 7262              0      No         No      13
# 7263              0     Yes         No      22
# 7264              0      No         No       2
# 7265              0     Yes        Yes      67
# 7266              0     Yes        Yes      63
#
# [7267 rows x 10 columns]

# %%
dados_phone = pd.json_normalize(dados['phone'])
dados = dados.drop(columns='phone').join(dados_phone)
dados_internet = pd.json_normalize(dados['internet'])
dados = dados.drop(columns='internet').join(dados_internet)
dados_account = pd.json_normalize(dados['account'])
dados = dados.drop(columns='account').join(dados_account)
dados
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# 0             Yes                No             DSL  ...          Yes
# 1             Yes               Yes             DSL  ...           No
# 2             Yes                No     Fiber optic  ...           No
# 3             Yes                No     Fiber optic  ...          Yes
# 4             Yes                No     Fiber optic  ...           No
# ...           ...               ...             ...  ...          ...
# 7262          Yes                No             DSL  ...           No
# 7263          Yes               Yes     Fiber optic  ...           No
# 7264          Yes                No             DSL  ...          Yes
# 7265          Yes                No             DSL  ...           No
# 7266           No  No phone service             DSL  ...          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No         Yes         Yes              No        One year
# 1                  No          No          No             Yes  Month-to-month
# 2                 Yes          No          No              No  Month-to-month
# 3                 Yes          No         Yes             Yes  Month-to-month
# 4                  No         Yes         Yes              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7262               No         Yes          No              No        One year
# 7263               No          No          No             Yes  Month-to-month
# 7264               No          No          No              No  Month-to-month
# 7265              Yes         Yes          No             Yes        Two year
# 7266              Yes          No         Yes             Yes        Two year
#
#      PaperlessBilling     PaymentMethod Charges.Monthly  Charges.Total
# 0                 Yes      Mailed check           65.60          593.3
# 1                  No      Mailed check           59.90          542.4
# 2                 Yes  Electronic check           73.90         280.85
# 3                 Yes  Electronic check           98.00        1237.85
# 4                 Yes      Mailed check           83.90          267.4
# ...               ...               ...             ...            ...
# 7262               No      Mailed check           55.15          742.9
# 7263              Yes  Electronic check           85.10         1873.7
# 7264              Yes      Mailed check           50.30          92.75
# 7265               No      Mailed check           67.85        4627.65
# 7266               No  Electronic check           59.00         3707.6
#
# [7267 rows x 21 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges.Monthly   7267 non-null   float64
#  20  Charges.Total     7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
dados.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
dados = dados.rename(columns={
    'customerID': 'clienteID',
    'Churn': 'churn',
    'gender': 'genero',
    'SeniorCitizen': 'Cidadao_Idoso',
    'Partner': 'Parceria',
    'Dependents': 'Dependentes',
    'tenure': 'Posse',
    'PhoneService': 'Servico_Telefonico',
    'MultipleLines': 'Varias_Linhas',
    'InternetService': 'Servico_de_Internet',
    'OnlineSecurity': 'Seguranca_Online',
    'OnlineBackup': 'Backup_Online',
    'DeviceProtection': 'Protecao_de_Dispositivo',
    'TechSupport': 'Suporte_Tecnico',
    'StreamingTV': 'Streaming_TV',
    'StreamingMovies': 'Streaming_Filmes',
    'Contract': 'Contrato',
    'PaperlessBilling': 'Faturamento_Sem_Papel',
    'PaymentMethod': 'Metodo_de_Pagamento',
    'Charges.Monthly': 'Encargos.Mensal',
    'Charges.Total': 'Encargos.Total'
})

# %%
dados
# Out:
#        clienteID churn  genero  Cidadao_Idoso Parceria Dependentes  Posse  \
# 0     0002-ORFBO    No  Female              0      Yes         Yes      9
# 1     0003-MKNFE    No    Male              0       No          No      9
# 2     0004-TLHLJ   Yes    Male              0       No          No      4
# 3     0011-IGKFF   Yes    Male              1      Yes          No     13
# 4     0013-EXCHZ   Yes  Female              1      Yes          No      3
# ...          ...   ...     ...            ...      ...         ...    ...
# 7262  9987-LUTYD    No  Female              0       No          No     13
# 7263  9992-RRAMN   Yes    Male              0      Yes          No     22
# 7264  9992-UJOEL    No    Male              0       No          No      2
# 7265  9993-LHIEB    No    Male              0      Yes         Yes     67
# 7266  9995-HOTOH    No    Male              0      Yes         Yes     63
#
#      Servico_Telefonico     Varias_Linhas Servico_de_Internet  ...  \
# 0                   Yes                No                 DSL  ...
# 1                   Yes               Yes                 DSL  ...
# 2                   Yes                No         Fiber optic  ...
# 3                   Yes                No         Fiber optic  ...
# 4                   Yes                No         Fiber optic  ...
# ...                 ...               ...                 ...  ...
# 7262                Yes                No                 DSL  ...
# 7263                Yes               Yes         Fiber optic  ...
# 7264                Yes                No                 DSL  ...
# 7265                Yes                No                 DSL  ...
# 7266                 No  No phone service                 DSL  ...
#
#      Backup_Online Protecao_de_Dispositivo Suporte_Tecnico Streaming_TV  \
# 0              Yes                      No             Yes          Yes
# 1               No                      No              No           No
# 2               No                     Yes              No           No
# 3              Yes                     Yes              No          Yes
# 4               No                      No             Yes          Yes
# ...            ...                     ...             ...          ...
# 7262            No                      No             Yes           No
# 7263            No                      No              No           No
# 7264           Yes                      No              No           No
# 7265            No                     Yes             Yes           No
# 7266           Yes                     Yes              No          Yes
#
#      Streaming_Filmes        Contrato Faturamento_Sem_Papel  \
# 0                  No        One year                   Yes
# 1                 Yes  Month-to-month                    No
# 2                  No  Month-to-month                   Yes
# 3                 Yes  Month-to-month                   Yes
# 4                  No  Month-to-month                   Yes
# ...               ...             ...                   ...
# 7262               No        One year                    No
# 7263              Yes  Month-to-month                   Yes
# 7264               No  Month-to-month                   Yes
# 7265              Yes        Two year                    No
# 7266              Yes        Two year                    No
#
#      Metodo_de_Pagamento Encargos.Mensal  Encargos.Total
# 0           Mailed check           65.60           593.3
# 1           Mailed check           59.90           542.4
# 2       Electronic check           73.90          280.85
# 3       Electronic check           98.00         1237.85
# 4           Mailed check           83.90           267.4
# ...                  ...             ...             ...
# 7262        Mailed check           55.15           742.9
# 7263    Electronic check           85.10          1873.7
# 7264        Mailed check           50.30           92.75
# 7265        Mailed check           67.85         4627.65
# 7266    Electronic check           59.00          3707.6
#
# [7267 rows x 21 columns]

# %%
dados[dados['Encargos.Total'] == ' ']['Contrato']
# Out:
# 975     Two year
# 1775    Two year
# 1955    Two year
# 2075    One year
# 2232    Two year
# 2308    Two year
# 2930    Two year
# 3134    Two year
# 3203    Two year
# 4169    Two year
# 5599    Two year
# Name: Contrato, dtype: object

# %%
dados.loc[2075]
# Out:
# clienteID                           2923-ARZLG
# churn                                       No
# genero                                    Male
# Cidadao_Idoso                                0
# Parceria                                   Yes
# Dependentes                                Yes
# Posse                                        0
# Servico_Telefonico                         Yes
# Varias_Linhas                               No
# Servico_de_Internet                         No
# Seguranca_Online           No internet service
# Backup_Online              No internet service
# Protecao_de_Dispositivo    No internet service
# Suporte_Tecnico            No internet service
# Streaming_TV               No internet service
# Streaming_Filmes           No internet service
# Contrato                              One year
# Faturamento_Sem_Papel                      Yes
# Metodo_de_Pagamento               Mailed check
# Encargos.Mensal                           19.7
# Encargos.Total
# Name: 2075, dtype: object

# %%
novo_valor = (dados.loc[2075, 'Encargos.Mensal']) * 12

# %%
dados.loc[2075, 'Encargos.Total'] = novo_valor

# %%
dados.loc[2075]
# Out:
# clienteID                           2923-ARZLG
# churn                                       No
# genero                                    Male
# Cidadao_Idoso                                0
# Parceria                                   Yes
# Dependentes                                Yes
# Posse                                        0
# Servico_Telefonico                         Yes
# Varias_Linhas                               No
# Servico_de_Internet                         No
# Seguranca_Online           No internet service
# Backup_Online              No internet service
# Protecao_de_Dispositivo    No internet service
# Suporte_Tecnico            No internet service
# Streaming_TV               No internet service
# Streaming_Filmes           No internet service
# Contrato                              One year
# Faturamento_Sem_Papel                      Yes
# Metodo_de_Pagamento               Mailed check
# Encargos.Mensal                           19.7
# Encargos.Total                           236.4
# Name: 2075, dtype: object

# %%
dados_idx = dados[dados['Encargos.Total'] == ' ']['Contrato'].index
dados_idx
# Out:
# Index([975, 1775, 1955, 2232, 2308, 2930, 3134, 3203, 4169, 5599], dtype='int64')

# %%
novo_valor = (dados.loc[dados_idx, 'Encargos.Mensal']) * 24
dados.loc[dados_idx, 'Encargos.Total'] = novo_valor
dados.loc[dados_idx]
# Out:
#        clienteID churn  genero  Cidadao_Idoso Parceria Dependentes  Posse  \
# 975   1371-DWPAZ    No  Female              0      Yes         Yes      0
# 1775  2520-SGTTA    No  Female              0      Yes         Yes      0
# 1955  2775-SEFEE    No    Male              0       No         Yes      0
# 2232  3115-CZMZD    No    Male              0       No         Yes      0
# 2308  3213-VVOLG    No    Male              0      Yes         Yes      0
# 2930  4075-WKNIU    No  Female              0      Yes         Yes      0
# 3134  4367-NUYAO    No    Male              0      Yes         Yes      0
# 3203  4472-LVYGI    No  Female              0      Yes         Yes      0
# 4169  5709-LVOEQ    No  Female              0      Yes         Yes      0
# 5599  7644-OMVMY    No    Male              0      Yes         Yes      0
#
#      Servico_Telefonico     Varias_Linhas Servico_de_Internet  ...  \
# 975                  No  No phone service                 DSL  ...
# 1775                Yes                No                  No  ...
# 1955                Yes               Yes                 DSL  ...
# 2232                Yes                No                  No  ...
# 2308                Yes               Yes                  No  ...
# 2930                Yes               Yes                 DSL  ...
# 3134                Yes               Yes                  No  ...
# 3203                 No  No phone service                 DSL  ...
# 4169                Yes                No                 DSL  ...
# 5599                Yes                No                  No  ...
#
#             Backup_Online Protecao_de_Dispositivo      Suporte_Tecnico  \
# 975                   Yes                     Yes                  Yes
# 1775  No internet service     No internet service  No internet service
# 1955                  Yes                      No                  Yes
# 2232  No internet service     No internet service  No internet service
# 2308  No internet service     No internet service  No internet service
# 2930                  Yes                     Yes                  Yes
# 3134  No internet service     No internet service  No internet service
# 3203                   No                     Yes                  Yes
# 4169                  Yes                     Yes                   No
# 5599  No internet service     No internet service  No internet service
#
#              Streaming_TV     Streaming_Filmes  Contrato  \
# 975                   Yes                   No  Two year
# 1775  No internet service  No internet service  Two year
# 1955                   No                   No  Two year
# 2232  No internet service  No internet service  Two year
# 2308  No internet service  No internet service  Two year
# 2930                  Yes                   No  Two year
# 3134  No internet service  No internet service  Two year
# 3203                  Yes                   No  Two year
# 4169                  Yes                  Yes  Two year
# 5599  No internet service  No internet service  Two year
#
#      Faturamento_Sem_Papel        Metodo_de_Pagamento Encargos.Mensal  \
# 975                     No    Credit card (automatic)           56.05
# 1775                    No               Mailed check           20.00
# 1955                   Yes  Bank transfer (automatic)           61.90
# 2232                    No               Mailed check           20.25
# 2308                    No               Mailed check           25.35
# 2930                    No               Mailed check           73.35
# 3134                    No               Mailed check           25.75
# 3203                   Yes  Bank transfer (automatic)           52.55
# 4169                    No               Mailed check           80.85
# 5599                    No               Mailed check           19.85
#
#       Encargos.Total
# 975           1345.2
# 1775           480.0
# 1955          1485.6
# 2232           486.0
# 2308           608.4
# 2930          1760.4
# 3134           618.0
# 3203          1261.2
# 4169          1940.4
# 5599           476.4
#
# [10 rows x 21 columns]

# %%
dados
# Out:
#        clienteID churn  genero  Cidadao_Idoso Parceria Dependentes  Posse  \
# 0     0002-ORFBO    No  Female              0      Yes         Yes      9
# 1     0003-MKNFE    No    Male              0       No          No      9
# 2     0004-TLHLJ   Yes    Male              0       No          No      4
# 3     0011-IGKFF   Yes    Male              1      Yes          No     13
# 4     0013-EXCHZ   Yes  Female              1      Yes          No      3
# ...          ...   ...     ...            ...      ...         ...    ...
# 7262  9987-LUTYD    No  Female              0       No          No     13
# 7263  9992-RRAMN   Yes    Male              0      Yes          No     22
# 7264  9992-UJOEL    No    Male              0       No          No      2
# 7265  9993-LHIEB    No    Male              0      Yes         Yes     67
# 7266  9995-HOTOH    No    Male              0      Yes         Yes     63
#
#      Servico_Telefonico     Varias_Linhas Servico_de_Internet  ...  \
# 0                   Yes                No                 DSL  ...
# 1                   Yes               Yes                 DSL  ...
# 2                   Yes                No         Fiber optic  ...
# 3                   Yes                No         Fiber optic  ...
# 4                   Yes                No         Fiber optic  ...
# ...                 ...               ...                 ...  ...
# 7262                Yes                No                 DSL  ...
# 7263                Yes               Yes         Fiber optic  ...
# 7264                Yes                No                 DSL  ...
# 7265                Yes                No                 DSL  ...
# 7266                 No  No phone service                 DSL  ...
#
#      Backup_Online Protecao_de_Dispositivo Suporte_Tecnico Streaming_TV  \
# 0              Yes                      No             Yes          Yes
# 1               No                      No              No           No
# 2               No                     Yes              No           No
# 3              Yes                     Yes              No          Yes
# 4               No                      No             Yes          Yes
# ...            ...                     ...             ...          ...
# 7262            No                      No             Yes           No
# 7263            No                      No              No           No
# 7264           Yes                      No              No           No
# 7265            No                     Yes             Yes           No
# 7266           Yes                     Yes              No          Yes
#
#      Streaming_Filmes        Contrato Faturamento_Sem_Papel  \
# 0                  No        One year                   Yes
# 1                 Yes  Month-to-month                    No
# 2                  No  Month-to-month                   Yes
# 3                 Yes  Month-to-month                   Yes
# 4                  No  Month-to-month                   Yes
# ...               ...             ...                   ...
# 7262               No        One year                    No
# 7263              Yes  Month-to-month                   Yes
# 7264               No  Month-to-month                   Yes
# 7265              Yes        Two year                    No
# 7266              Yes        Two year                    No
#
#      Metodo_de_Pagamento Encargos.Mensal  Encargos.Total
# 0           Mailed check           65.60           593.3
# 1           Mailed check           59.90           542.4
# 2       Electronic check           73.90          280.85
# 3       Electronic check           98.00         1237.85
# 4           Mailed check           83.90           267.4
# ...                  ...             ...             ...
# 7262        Mailed check           55.15           742.9
# 7263    Electronic check           85.10          1873.7
# 7264        Mailed check           50.30           92.75
# 7265        Mailed check           67.85         4627.65
# 7266    Electronic check           59.00          3707.6
#
# [7267 rows x 21 columns]

# %%
dados[dados['Encargos.Total'] == ' ']
# Out:
# Empty DataFrame
# Columns: [clienteID, churn, genero, Cidadao_Idoso, Parceria, Dependentes, Posse, Servico_Telefonico, Varias_Linhas, Servico_de_Internet, Seguranca_Online, Backup_Online, Protecao_de_Dispositivo, Suporte_Tecnico, Streaming_TV, Streaming_Filmes, Contrato, Faturamento_Sem_Papel, Metodo_de_Pagamento, Encargos.Mensal, Encargos.Total]
# Index: []
#
# [0 rows x 21 columns]

# %%
dados
# Out:
#        clienteID churn  genero  Cidadao_Idoso Parceria Dependentes  Posse  \
# 0     0002-ORFBO    No  Female              0      Yes         Yes      9
# 1     0003-MKNFE    No    Male              0       No          No      9
# 2     0004-TLHLJ   Yes    Male              0       No          No      4
# 3     0011-IGKFF   Yes    Male              1      Yes          No     13
# 4     0013-EXCHZ   Yes  Female              1      Yes          No      3
# ...          ...   ...     ...            ...      ...         ...    ...
# 7262  9987-LUTYD    No  Female              0       No          No     13
# 7263  9992-RRAMN   Yes    Male              0      Yes          No     22
# 7264  9992-UJOEL    No    Male              0       No          No      2
# 7265  9993-LHIEB    No    Male              0      Yes         Yes     67
# 7266  9995-HOTOH    No    Male              0      Yes         Yes     63
#
#      Servico_Telefonico     Varias_Linhas Servico_de_Internet  ...  \
# 0                   Yes                No                 DSL  ...
# 1                   Yes               Yes                 DSL  ...
# 2                   Yes                No         Fiber optic  ...
# 3                   Yes                No         Fiber optic  ...
# 4                   Yes                No         Fiber optic  ...
# ...                 ...               ...                 ...  ...
# 7262                Yes                No                 DSL  ...
# 7263                Yes               Yes         Fiber optic  ...
# 7264                Yes                No                 DSL  ...
# 7265                Yes                No                 DSL  ...
# 7266                 No  No phone service                 DSL  ...
#
#      Backup_Online Protecao_de_Dispositivo Suporte_Tecnico Streaming_TV  \
# 0              Yes                      No             Yes          Yes
# 1               No                      No              No           No
# 2               No                     Yes              No           No
# 3              Yes                     Yes              No          Yes
# 4               No                      No             Yes          Yes
# ...            ...                     ...             ...          ...
# 7262            No                      No             Yes           No
# 7263            No                      No              No           No
# 7264           Yes                      No              No           No
# 7265            No                     Yes             Yes           No
# 7266           Yes                     Yes              No          Yes
#
#      Streaming_Filmes        Contrato Faturamento_Sem_Papel  \
# 0                  No        One year                   Yes
# 1                 Yes  Month-to-month                    No
# 2                  No  Month-to-month                   Yes
# 3                 Yes  Month-to-month                   Yes
# 4                  No  Month-to-month                   Yes
# ...               ...             ...                   ...
# 7262               No        One year                    No
# 7263              Yes  Month-to-month                   Yes
# 7264               No  Month-to-month                   Yes
# 7265              Yes        Two year                    No
# 7266              Yes        Two year                    No
#
#      Metodo_de_Pagamento Encargos.Mensal  Encargos.Total
# 0           Mailed check           65.60           593.3
# 1           Mailed check           59.90           542.4
# 2       Electronic check           73.90          280.85
# 3       Electronic check           98.00         1237.85
# 4           Mailed check           83.90           267.4
# ...                  ...             ...             ...
# 7262        Mailed check           55.15           742.9
# 7263    Electronic check           85.10          1873.7
# 7264        Mailed check           50.30           92.75
# 7265        Mailed check           67.85         4627.65
# 7266    Electronic check           59.00          3707.6
#
# [7267 rows x 21 columns]

# %%
dados_sem_churn_vazio = dados[dados['churn'] != ''].copy()

# %%
dados_sem_churn_vazio[dados_sem_churn_vazio['churn'] == '']
# Out:
# Empty DataFrame
# Columns: [clienteID, churn, genero, Cidadao_Idoso, Parceria, Dependentes, Posse, Servico_Telefonico, Varias_Linhas, Servico_de_Internet, Seguranca_Online, Backup_Online, Protecao_de_Dispositivo, Suporte_Tecnico, Streaming_TV, Streaming_Filmes, Contrato, Faturamento_Sem_Papel, Metodo_de_Pagamento, Encargos.Mensal, Encargos.Total]
# Index: []
#
# [0 rows x 21 columns]

# %%
dados_sem_churn_vazio.reset_index(drop=True, inplace=True)

# %%
dados_sem_churn_vazio
# Out:
#        clienteID churn  genero  Cidadao_Idoso Parceria Dependentes  Posse  \
# 0     0002-ORFBO    No  Female              0      Yes         Yes      9
# 1     0003-MKNFE    No    Male              0       No          No      9
# 2     0004-TLHLJ   Yes    Male              0       No          No      4
# 3     0011-IGKFF   Yes    Male              1      Yes          No     13
# 4     0013-EXCHZ   Yes  Female              1      Yes          No      3
# ...          ...   ...     ...            ...      ...         ...    ...
# 7038  9987-LUTYD    No  Female              0       No          No     13
# 7039  9992-RRAMN   Yes    Male              0      Yes          No     22
# 7040  9992-UJOEL    No    Male              0       No          No      2
# 7041  9993-LHIEB    No    Male              0      Yes         Yes     67
# 7042  9995-HOTOH    No    Male              0      Yes         Yes     63
#
#      Servico_Telefonico     Varias_Linhas Servico_de_Internet  ...  \
# 0                   Yes                No                 DSL  ...
# 1                   Yes               Yes                 DSL  ...
# 2                   Yes                No         Fiber optic  ...
# 3                   Yes                No         Fiber optic  ...
# 4                   Yes                No         Fiber optic  ...
# ...                 ...               ...                 ...  ...
# 7038                Yes                No                 DSL  ...
# 7039                Yes               Yes         Fiber optic  ...
# 7040                Yes                No                 DSL  ...
# 7041                Yes                No                 DSL  ...
# 7042                 No  No phone service                 DSL  ...
#
#      Backup_Online Protecao_de_Dispositivo Suporte_Tecnico Streaming_TV  \
# 0              Yes                      No             Yes          Yes
# 1               No                      No              No           No
# 2               No                     Yes              No           No
# 3              Yes                     Yes              No          Yes
# 4               No                      No             Yes          Yes
# ...            ...                     ...             ...          ...
# 7038            No                      No             Yes           No
# 7039            No                      No              No           No
# 7040           Yes                      No              No           No
# 7041            No                     Yes             Yes           No
# 7042           Yes                     Yes              No          Yes
#
#      Streaming_Filmes        Contrato Faturamento_Sem_Papel  \
# 0                  No        One year                   Yes
# 1                 Yes  Month-to-month                    No
# 2                  No  Month-to-month                   Yes
# 3                 Yes  Month-to-month                   Yes
# 4                  No  Month-to-month                   Yes
# ...               ...             ...                   ...
# 7038               No        One year                    No
# 7039              Yes  Month-to-month                   Yes
# 7040               No  Month-to-month                   Yes
# 7041              Yes        Two year                    No
# 7042              Yes        Two year                    No
#
#      Metodo_de_Pagamento Encargos.Mensal  Encargos.Total
# 0           Mailed check           65.60           593.3
# 1           Mailed check           59.90           542.4
# 2       Electronic check           73.90          280.85
# 3       Electronic check           98.00         1237.85
# 4           Mailed check           83.90           267.4
# ...                  ...             ...             ...
# 7038        Mailed check           55.15           742.9
# 7039    Electronic check           85.10          1873.7
# 7040        Mailed check           50.30           92.75
# 7041        Mailed check           67.85         4627.65
# 7042    Electronic check           59.00          3707.6
#
# [7043 rows x 21 columns]

# %%
dados2 = dados_sem_churn_vazio.copy()

# %%
dados2.duplicated().sum()
# Out:
# np.int64(0)

# %%
dados2.isna().sum()
# Out:
# clienteID                  0
# churn                      0
# genero                     0
# Cidadao_Idoso              0
# Parceria                   0
# Dependentes                0
# Posse                      0
# Servico_Telefonico         0
# Varias_Linhas              0
# Servico_de_Internet        0
# Seguranca_Online           0
# Backup_Online              0
# Protecao_de_Dispositivo    0
# Suporte_Tecnico            0
# Streaming_TV               0
# Streaming_Filmes           0
# Contrato                   0
# Faturamento_Sem_Papel      0
# Metodo_de_Pagamento        0
# Encargos.Mensal            0
# Encargos.Total             0
# dtype: int64

# %%
dados2[dados2['Dependentes'] == '']
# Out:
# Empty DataFrame
# Columns: [clienteID, churn, genero, Cidadao_Idoso, Parceria, Dependentes, Posse, Servico_Telefonico, Varias_Linhas, Servico_de_Internet, Seguranca_Online, Backup_Online, Protecao_de_Dispositivo, Suporte_Tecnico, Streaming_TV, Streaming_Filmes, Contrato, Faturamento_Sem_Papel, Metodo_de_Pagamento, Encargos.Mensal, Encargos.Total]
# Index: []
#
# [0 rows x 21 columns]

# %%
dados2.head()
# Out:
#     clienteID churn  genero  Cidadao_Idoso Parceria Dependentes  Posse  \
# 0  0002-ORFBO    No  Female              0      Yes         Yes      9
# 1  0003-MKNFE    No    Male              0       No          No      9
# 2  0004-TLHLJ   Yes    Male              0       No          No      4
# 3  0011-IGKFF   Yes    Male              1      Yes          No     13
# 4  0013-EXCHZ   Yes  Female              1      Yes          No      3
#
#   Servico_Telefonico Varias_Linhas Servico_de_Internet  ... Backup_Online  \
# 0                Yes            No                 DSL  ...           Yes
# 1                Yes           Yes                 DSL  ...            No
# 2                Yes            No         Fiber optic  ...            No
# 3                Yes            No         Fiber optic  ...           Yes
# 4                Yes            No         Fiber optic  ...            No
#
#   Protecao_de_Dispositivo Suporte_Tecnico Streaming_TV Streaming_Filmes  \
# 0                      No             Yes          Yes               No
# 1                      No              No           No              Yes
# 2                     Yes              No           No               No
# 3                     Yes              No          Yes              Yes
# 4                      No             Yes          Yes               No
#
#          Contrato Faturamento_Sem_Papel Metodo_de_Pagamento Encargos.Mensal  \
# 0        One year                   Yes        Mailed check            65.6
# 1  Month-to-month                    No        Mailed check            59.9
# 2  Month-to-month                   Yes    Electronic check            73.9
# 3  Month-to-month                   Yes    Electronic check            98.0
# 4  Month-to-month                   Yes        Mailed check            83.9
#
#    Encargos.Total
# 0           593.3
# 1           542.4
# 2          280.85
# 3         1237.85
# 4           267.4
#
# [5 rows x 21 columns]

# %%
dados2.describe()
# Out:
#        Cidadao_Idoso        Posse  Encargos.Mensal
# count    7043.000000  7043.000000      7043.000000
# mean        0.162147    32.371149        64.761692
# std         0.368612    24.559481        30.090047
# min         0.000000     0.000000        18.250000
# 25%         0.000000     9.000000        35.500000
# 50%         0.000000    29.000000        70.350000
# 75%         0.000000    55.000000        89.850000
# max         1.000000    72.000000       118.750000

# %%
for col in dados2.columns:
  print(f'Coluna: {col}')
  print(dados2[col].unique())
  print('-' * 30)
# Out:
# Coluna: clienteID
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# ------------------------------
# Coluna: churn
# ['No' 'Yes']
# ------------------------------
# Coluna: genero
# ['Female' 'Male']
# ------------------------------
# Coluna: Cidadao_Idoso
# [0 1]
# ------------------------------
# Coluna: Parceria
# ['Yes' 'No']
# ------------------------------
# Coluna: Dependentes
# ['Yes' 'No']
# ------------------------------
# Coluna: Posse
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 37 49 66 67
#  20 43 59 12 27  2 25 29 14 35 64 39 40 11  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 31 36 17 18 51 38 42
#   0]
# ------------------------------
# Coluna: Servico_Telefonico
# ['Yes' 'No']
# ------------------------------
# Coluna: Varias_Linhas
# ['No' 'Yes' 'No phone service']
# ------------------------------
# Coluna: Servico_de_Internet
# ['DSL' 'Fiber optic' 'No']
# ------------------------------
# Coluna: Seguranca_Online
# ['No' 'Yes' 'No internet service']
# ------------------------------
# Coluna: Backup_Online
# ['Yes' 'No' 'No internet service']
# ------------------------------
# Coluna: Protecao_de_Dispositivo
# ['No' 'Yes' 'No internet service']
# ------------------------------
# Coluna: Suporte_Tecnico
# ['Yes' 'No' 'No internet service']
# ------------------------------
# Coluna: Streaming_TV
# ['Yes' 'No' 'No internet service']
# ------------------------------
# Coluna: Streaming_Filmes
# ['No' 'Yes' 'No internet service']
# ------------------------------
# Coluna: Contrato
# ['One year' 'Month-to-month' 'Two year']
# ------------------------------
# Coluna: Faturamento_Sem_Papel
# ['Yes' 'No']
# ------------------------------
# Coluna: Metodo_de_Pagamento
# ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']
# ------------------------------
# Coluna: Encargos.Mensal
# [65.6  59.9  73.9  ... 91.75 68.8  67.85]
# ------------------------------
# Coluna: Encargos.Total
# ['593.3' '542.4' '280.85' ... '742.9' '4627.65' '3707.6']
# ------------------------------

# %%
colunas = ['churn', 'genero', 'Cidadao_Idoso', 'Parceria', 'Dependentes', 'Servico_Telefonico', 'Faturamento_Sem_Papel']

# %%
mapeamento = {
    'No': 0,
    'Yes': 1,
    'Male': 0,
    'Female': 1
}

# %%
dados2[colunas] = dados2[colunas].replace(mapeamento)
dados2
# Out:
# <ipython-input-39-a47be7c4772b>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dados2[colunas] = dados2[colunas].replace(mapeamento)
#        clienteID  churn  genero  Cidadao_Idoso  Parceria  Dependentes  Posse  \
# 0     0002-ORFBO      0       1              0         1            1      9
# 1     0003-MKNFE      0       0              0         0            0      9
# 2     0004-TLHLJ      1       0              0         0            0      4
# 3     0011-IGKFF      1       0              1         1            0     13
# 4     0013-EXCHZ      1       1              1         1            0      3
# ...          ...    ...     ...            ...       ...          ...    ...
# 7038  9987-LUTYD      0       1              0         0            0     13
# 7039  9992-RRAMN      1       0              0         1            0     22
# 7040  9992-UJOEL      0       0              0         0            0      2
# 7041  9993-LHIEB      0       0              0         1            1     67
# 7042  9995-HOTOH      0       0              0         1            1     63
#
#       Servico_Telefonico     Varias_Linhas Servico_de_Internet  ...  \
# 0                      1                No                 DSL  ...
# 1                      1               Yes                 DSL  ...
# 2                      1                No         Fiber optic  ...
# 3                      1                No         Fiber optic  ...
# 4                      1                No         Fiber optic  ...
# ...                  ...               ...                 ...  ...
# 7038                   1                No                 DSL  ...
# 7039                   1               Yes         Fiber optic  ...
# 7040                   1                No                 DSL  ...
# 7041                   1                No                 DSL  ...
# 7042                   0  No phone service                 DSL  ...
#
#      Backup_Online Protecao_de_Dispositivo Suporte_Tecnico Streaming_TV  \
# 0              Yes                      No             Yes          Yes
# 1               No                      No              No           No
# 2               No                     Yes              No           No
# 3              Yes                     Yes              No          Yes
# 4               No                      No             Yes          Yes
# ...            ...                     ...             ...          ...
# 7038            No                      No             Yes           No
# 7039            No                      No              No           No
# 7040           Yes                      No              No           No
# 7041            No                     Yes             Yes           No
# 7042           Yes                     Yes              No          Yes
#
#      Streaming_Filmes        Contrato Faturamento_Sem_Papel  \
# 0                  No        One year                     1
# 1                 Yes  Month-to-month                     0
# 2                  No  Month-to-month                     1
# 3                 Yes  Month-to-month                     1
# 4                  No  Month-to-month                     1
# ...               ...             ...                   ...
# 7038               No        One year                     0
# 7039              Yes  Month-to-month                     1
# 7040               No  Month-to-month                     1
# 7041              Yes        Two year                     0
# 7042              Yes        Two year                     0
#
#       Metodo_de_Pagamento Encargos.Mensal  Encargos.Total
# 0            Mailed check           65.60           593.3
# 1            Mailed check           59.90           542.4
# 2        Electronic check           73.90          280.85
# 3        Electronic check           98.00         1237.85
# 4            Mailed check           83.90           267.4
# ...                   ...             ...             ...
# 7038         Mailed check           55.15           742.9
# 7039     Electronic check           85.10          1873.7
# 7040         Mailed check           50.30           92.75
# 7041         Mailed check           67.85         4627.65
# 7042     Electronic check           59.00          3707.6
#
# [7043 rows x 21 columns]

# %%
for col in dados2.columns:
  print(f'Coluna: {col}')
  print(dados2[col].unique())
  print('-' * 30)
# Out:
# Coluna: clienteID
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# ------------------------------
# Coluna: churn
# [0 1]
# ------------------------------
# Coluna: genero
# [1 0]
# ------------------------------
# Coluna: Cidadao_Idoso
# [0 1]
# ------------------------------
# Coluna: Parceria
# [1 0]
# ------------------------------
# Coluna: Dependentes
# [1 0]
# ------------------------------
# Coluna: Posse
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 37 49 66 67
#  20 43 59 12 27  2 25 29 14 35 64 39 40 11  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 31 36 17 18 51 38 42
#   0]
# ------------------------------
# Coluna: Servico_Telefonico
# [1 0]
# ------------------------------
# Coluna: Varias_Linhas
# ['No' 'Yes' 'No phone service']
# ------------------------------
# Coluna: Servico_de_Internet
# ['DSL' 'Fiber optic' 'No']
# ------------------------------
# Coluna: Seguranca_Online
# ['No' 'Yes' 'No internet service']
# ------------------------------
# Coluna: Backup_Online
# ['Yes' 'No' 'No internet service']
# ------------------------------
# Coluna: Protecao_de_Dispositivo
# ['No' 'Yes' 'No internet service']
# ------------------------------
# Coluna: Suporte_Tecnico
# ['Yes' 'No' 'No internet service']
# ------------------------------
# Coluna: Streaming_TV
# ['Yes' 'No' 'No internet service']
# ------------------------------
# Coluna: Streaming_Filmes
# ['No' 'Yes' 'No internet service']
# ------------------------------
# Coluna: Contrato
# ['One year' 'Month-to-month' 'Two year']
# ------------------------------
# Coluna: Faturamento_Sem_Papel
# [1 0]
# ------------------------------
# Coluna: Metodo_de_Pagamento
# ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']
# ------------------------------
# Coluna: Encargos.Mensal
# [65.6  59.9  73.9  ... 91.75 68.8  67.85]
# ------------------------------
# Coluna: Encargos.Total
# ['593.3' '542.4' '280.85' ... '742.9' '4627.65' '3707.6']
# ------------------------------

# %%
traducao = {
    'Yes': 'Sim',
    'No': 'Não',
    'No phone service': 'Sem serviço de telefone',
    'Fiber optic': 'Fibra Otica',
    'No internet service': 'Sem Serviço de internet',
    'One year': 'Um Ano',
    'Month-to-month': 'Mes a Mes',
    'Two year': 'Dois anos',
    'Mailed check': 'Cheque enviado pelo correio',
    'Electronic check': 'Correio eletrônico',
    'Credit card (automatic)': 'Cartão de crédito(automático)',
    'Bank transfer (automatic)': 'Transferência bancária(automática)'
}

# %%
dados2.replace(traducao, inplace=True)

# %%
dados2
# Out:
#        clienteID  churn  genero  Cidadao_Idoso  Parceria  Dependentes  Posse  \
# 0     0002-ORFBO      0       1              0         1            1      9
# 1     0003-MKNFE      0       0              0         0            0      9
# 2     0004-TLHLJ      1       0              0         0            0      4
# 3     0011-IGKFF      1       0              1         1            0     13
# 4     0013-EXCHZ      1       1              1         1            0      3
# ...          ...    ...     ...            ...       ...          ...    ...
# 7038  9987-LUTYD      0       1              0         0            0     13
# 7039  9992-RRAMN      1       0              0         1            0     22
# 7040  9992-UJOEL      0       0              0         0            0      2
# 7041  9993-LHIEB      0       0              0         1            1     67
# 7042  9995-HOTOH      0       0              0         1            1     63
#
#       Servico_Telefonico            Varias_Linhas Servico_de_Internet  ...  \
# 0                      1                      Não                 DSL  ...
# 1                      1                      Sim                 DSL  ...
# 2                      1                      Não         Fibra Otica  ...
# 3                      1                      Não         Fibra Otica  ...
# 4                      1                      Não         Fibra Otica  ...
# ...                  ...                      ...                 ...  ...
# 7038                   1                      Não                 DSL  ...
# 7039                   1                      Sim         Fibra Otica  ...
# 7040                   1                      Não                 DSL  ...
# 7041                   1                      Não                 DSL  ...
# 7042                   0  Sem serviço de telefone                 DSL  ...
#
#      Backup_Online Protecao_de_Dispositivo Suporte_Tecnico Streaming_TV  \
# 0              Sim                     Não             Sim          Sim
# 1              Não                     Não             Não          Não
# 2              Não                     Sim             Não          Não
# 3              Sim                     Sim             Não          Sim
# 4              Não                     Não             Sim          Sim
# ...            ...                     ...             ...          ...
# 7038           Não                     Não             Sim          Não
# 7039           Não                     Não             Não          Não
# 7040           Sim                     Não             Não          Não
# 7041           Não                     Sim             Sim          Não
# 7042           Sim                     Sim             Não          Sim
#
#      Streaming_Filmes   Contrato Faturamento_Sem_Papel  \
# 0                 Não     Um Ano                     1
# 1                 Sim  Mes a Mes                     0
# 2                 Não  Mes a Mes                     1
# 3                 Sim  Mes a Mes                     1
# 4                 Não  Mes a Mes                     1
# ...               ...        ...                   ...
# 7038              Não     Um Ano                     0
# 7039              Sim  Mes a Mes                     1
# 7040              Não  Mes a Mes                     1
# 7041              Sim  Dois anos                     0
# 7042              Sim  Dois anos                     0
#
#               Metodo_de_Pagamento Encargos.Mensal  Encargos.Total
# 0     Cheque enviado pelo correio           65.60           593.3
# 1     Cheque enviado pelo correio           59.90           542.4
# 2              Correio eletrônico           73.90          280.85
# 3              Correio eletrônico           98.00         1237.85
# 4     Cheque enviado pelo correio           83.90           267.4
# ...                           ...             ...             ...
# 7038  Cheque enviado pelo correio           55.15           742.9
# 7039           Correio eletrônico           85.10          1873.7
# 7040  Cheque enviado pelo correio           50.30           92.75
# 7041  Cheque enviado pelo correio           67.85         4627.65
# 7042           Correio eletrônico           59.00          3707.6
#
# [7043 rows x 21 columns]
